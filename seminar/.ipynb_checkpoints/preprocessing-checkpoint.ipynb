# %%
import pandas as pd

# %%
df = pd.read_csv("parse_total.csv", sep='\t', encoding = 'utf-16')

# %%
contents = pd.Series()

# %%
def split(x):
    contents.update(x.split('. '))
content_raw = df['content'].agg(split)

# %%
contents
# Out:
# {'',
#  'Siêu phẩm, không làm mình thất vọng',
#  'Không thấy có thông báo gì',
#  'sẽ ủng hộ ĐMX nhiều',
#  'Máy dùng rất ổn',
#  'Nhiều tính năng hay chưa mò hết',
#  'Mình mới bảo Mắc quá không sửa nữa, đem điện thoại về thì nó không cảm ứng được luôn, còn nút nguồn là xài được (Lúc đầu chưa sửa vẫn cảm ứng được)',
#  'Sản phẩm rất tốt xài mượt mà chiến game bao phê mọi game nặng như PUG, Asphalt 8 chơi cực mượt mà, đồ họa đổ bóng nhìn đẹp thôi rồi chỉ tiếc pin không được như mong đợi.',
#  'Máy nhỏ gọn, pin cực trâu',
#  'Ngoài ra mọi thứ đều rất ok',
#  'Camera ,...',
#  'Rất tuyệt! Chạy mượt! Nói chung là OK, chỉ tội cái nổi là 16Gb bộ nhớ còn quá kém',
#  'Như tôi dùng cơ bản quá tốt.chụp hình đẹp, nên mua, vừa túi tiền.',
#  'Mỗi cái là pin hết nhanh + ko vào đc store game app thôi',
#  'Đẹp chuẩn',
#  'Nó giúp mình ứng dụng 4.0 trong công việc',
#  'zoom nhiễu',
#  'Pin trâu',
#  'Camera tốt, hiệu năng mạnh',
#  'Nhân viên tgdd thì khỏi bàn rồi, rất nhiệt tình!',
#  'Camera sau hơi nhô lên chút nhưng không sao',
#  'Mới trải nghiệm nhưng galaxy chỉ được lúc đầu về sau lag lắm',
#  'Miui 9 đẹp 7',
#  'Máy vẫn chạy tốt',
#  'Ông hòang của máy bàn phím.',
#  'Loa oppp f11 pro khi bị bụi bám thì vệ sinh bằng cách nào,sp tốt,cam đẹp,thiết kế đẹp',
#  'Nhân viên TGDĐ, ĐMX nhiệt tình, vui vẻ',
#  'Noi chung về cau hình ti ổn định chơi game mượt ko bị đơ ',
#  'Nhất là khoản chụp góc rộng, quá duyệt!',
#  'Sóng gió bao la',
#  'Em đã mua một thời gian và thấy máy f7 xài tốt',
#  'Wtf chả hiểu s 10tr mà lại vậy..',
#  'Bao da ốp lưng chính hãng của Apple vẫn còn hơi mắc (nắp gập gần 3 triệu)',
#  'Riêng từ ngày 21-7-2018 mình nhận dc 1 bản cập nhật phần mềm và từ lúc cập nhật xong mình thấy pin rất nhanh hết, mình bật điện thoại trên máy bay lúc 22h đến 6h sáng mà pin tut 28% pin luon',
#  'Không cài đc hack game như máy samsung.',
#  'Cạn lời khen',
#  'sản phẩm pin khỏe, dùng bền,loa to, chụp anh đẹp cầm vừa tay, đẹp đep đẹp đẹp đẹp đẹp đẹp đẹp',
#  'Màn hình máy rất đẹp, chơi game, xem phim gì nhìn cũng đã lắm, xài còn lắc mà máy rẻ thì đành phải chấp nhận hạn chế bớt cài các ứng dụng nặng vậy.',
#  'Muốn trả góp thì cần mang j ạ tại e chưa có bằng lái chỉ có cmnd với sổ hộ khẩu đc k ạ cmnd và sổ hộ khẩu gốc hay photo ạ',
#  'lời khuyên cho các bạn nào mới mua iphone rẻ thì nên iphone se đi mắc hơn iphone 5 1 chút nhưng cấu hình lại ngang ngửa 6 và giá cũng mềm, có màn hình bé thôi nhưng giá vậy là rất ok rồi.',
#  'Cảm giác dùng rất sướng, kô có đến nỗi tệ như nhiều đấng dùng smartphone quen rồi vào phán..',
#  'Điện thoại tầm giá như này là quá ok rồi ạ , chơi được những dạng game nhẹ + fb , zalo , mess ,..',
#  'Mình đăng ký nhận diện khuôn mặt buổi tối,sáng mai mở máy để thì máy không nhận ra khuôn mặt',
#  'Vào mạng nhanh',
#  'Hơi giật khi đánh liên quân Mobile',
#  'Nói chung là ngon hơn nhiều so với các hảng khác.',
#  'nói chung sẽ không hối hận khi mua sản phẩm này',
#  'Chỉ có điều nhận diện vân tay không được nhạy.',
#  'Màn hình cảm ứng nhạy, pin chơi game khoảng 5 tiếng',
#  'Chơi game xong vô nhắn tin liền thì chịu luôn ấn chữ này nhảy chữ nọ',
#  'Cấu hình khủng , Ram 3G mà giá tốt quá , dùng rất mượt , máy thiết kế đẹp , chụp hình chuẩn nét',
#  'Mình rất thich sản phẩm này',
#  'thiết kế đẹp, dễ sử dụng, cấu hình máy nokia này ổn định, vào mạng nhanh,pin dũng cũng được lâu',
#  'Mọi thứ đều ổn chỉ có bắt wi-fi là yếu thôi ( máy mình bị vậy ) Còn tất cả rất OK',
#  'Nhưng tháng thứ 4 về sau máy luôn bị đơ và lag',
#  'sản phẩm dùng tạm chấp nhận được, pin trâu, màn hình lớn, camera tạm , thiệt kế sang trọng',
#  'Đọc báo lâu hơn, xem video khoang 3 tiếng hơn( xài 3 g)',
#  'Giá thì quá rẻ',
#  'Rất hài lòng về cách phục vụ và tư vấn về sản phẩm, sản phẩm tốt, sử dụng rất tốt, tuyệt vời',
#  'Máy đẹp, nhỏ gọn',
#  'Máy tạm được với phân khúc về giá chỉ thất vọng về pin nhanh tụt.',
#  'Màn hình khóa không xem đc thông báo..hết',
#  'Sản phẩm tốt, thiết kế đẹp, hiệu năng cao, trong tầm giá này khó mà tìm được trong cùng phân khúc',
#  'Camera thi tạm được .sóng yếu,wifi cũng bắt sóng yếu',
#  'Camera tốt cho hình ảnh chân thực',
#  'Up lên 7.0.1 rất mượt',
#  'Nhân viên phục vụ tận tình, thiết nghĩ để bạn nữ tiếp mình thì ok hơn 😂.',
#  'Càng về sau chất lượng càng giảm so với trước cả về chất và lượng : pin, máy, cấu hình',
#  'Nhân viên tiếp đãi rất nhiệt tình',
#  'Gam 1g thì bị lag không nói gì..',
#  'Cho e hỏi lỗi này là gì ạ, anh chị có thể giải thích cho e đc ko ạ',
#  'Khi t gửi dòng đánh giá này đứng máy 6 lần đơ màn hình bàn phím ít nhất 4 giây',
#  "Chơi game 30' tụt 10%",
#  'Cảm biến vân tay ko nhạy',
#  'được khi đang lên 1 số app, và còn lỗi tiết kiệm pin sau khi cập nhật android 9( mình nghĩ là lỗi), sau khi bật tiết kiệm pin thì 1 thời gian đầu máy k sang trạng thái tiết kiệm pin như là ấn nút đa nhiệm nó vẫn rung lên mặc dù ở phiên bản trước nó sẽ tắt rung ngay khi tiết kiệm pin dc bật mà android9 lần này phải mất 1 tg mới tắt rung',
#  'Nên tăng thêm dung lượng.',
#  'Moi mua được một tuần cảm thấy tuyệt vời, dung là cựu vương đã quay cho lại thật rồi.',
#  'cảm ưng nhạy',
#  'Tôi mua điện thoại này được 1 năm.Không hiểu sao mấy tháng gần đây cứ 8 h sáng nó tự bật đài 89 mhz dù đã tắt nguồn nhưng vẫn phát tiếng',
#  'Sản phẩm ra mắt 4 năm nhưng vẫn dùng ngon và mượt so với tầm giá Sắp đc câph nhật ios 13',
#  'Nhưng xem video không nét cho lắm',
#  'Máy dùng tốt pin khỏe, cam chụp ảo :v nc là oke hết',
#  'Nhược điểm là hiệu năng hơi tệ để chơi game, tầm này mua Xiaomi Redmi Note 4 chơi game vẫn ổn hơn',
#  'máy siêu nhạy',
#  'Mọi thứ thì thấy ok mà sao không biết màn hình mình có bị gì ko mà nửa màn hình bên phải khi đọc chữ thì thấy nó bị nhòe nhòe',
#  'chức năng always on display rất tiện lợi ',
#  '***Bluetooth 2.0 nên tốc độ hơi chậm & không xa, cũng không điều chỉnh gì được hết.',
#  'Còn cày game thì nên chọn đt có pin tầm 4K trở lên, chip S660 tiến trình 14nm nên cũg k thể nào so sánh vs chíp 10nm hay 7 hoặc 8nm đc',
#  'Trong tầm giá này là ngon rồi có laz mà ít pin siêu trâu mà thích nhất là có tặng bao luôn và nút điều hướng ngoài màng hình.',
#  'máy đẹp, pin ổn, nghe nhạc hay, rất ok vs sản phẩm này',
#  'Điện thoại rất tốt sài rất OK',
#  '=== > tóm lại: với mức giá rẻ này và những ưu điểm thì mình nghĩ nó xứng đáng để bạn mua mà không phải đắn đo suy nghĩ',
#  'Máy cảm ứng rất nhanh, thiết kế sang trọng, nhỏ gọn, màu sắc phù hợp với lứa tuổi.Mẹ minh sài rất ưng ý',
#  'nói chung là tuyệt vời vs sản phẩm này',
#  'Ức chế.',
#  'Chơi game nặng cũng ok lắm ak ngen',
#  'mình mua điện thoại này hơn 1 năm sài vẫn ngon lành không bị trục trặc gì...rớt muốn banh màng hình mà vẫn sài ngon lành...chạy mướt..các bạn yên tam sử dụng..ngon bổ rẻ!',
#  'dung lượng pin 3000 maH nên sử dụng được khá lâu, cảm ứng mượt nhạy, chụp hình cũng sáng, đẹp',
#  'Mọi người phàn nàn về phát wifi là mất nhiều bước nhưng vào cũng chưa đến 5s là được',
#  'Cấu hình chạy mạnh',
#  'Up lên Android 9 bị lỗi pin thích ứng, khi sử dụng dễ bị đè tay vào loa, không thể sạc qua cổng USB laptop khi laptop ở chế độ sleep.',
#  'Ai hay chụp ảnh k nên mua',
#  'Máy hay nóng cứ tưởng máy bật nguồn pin sử dụng có 1ngày',
#  'Mình là dân ICT mua e này về cũng hơi giật lag có up rom lại chạy cũng mượt như hàng tầm trung',
#  'Cấu hinh tuong đối ôn thiết kế đẹp sang trọng.nhỏ gọn.màu sắc rất ok',
#  'Mình mua đã 1 tuần, cảm nhận dùng ok, pin đủ dùng trong ngày, có sạc nhanh nên không lo gì cả',
#  'Máy nhìn đẹp nhưng bắt wifi quá kém chơi game giật lag thấy rõ nói chung là không hài lòng lắm màn hình hiển thị ko đẹp chụp ảnh cam trước tệ pin hao nhanh',
#  'Máy sài tốt ..nhân viên nhiệt tình, máy dùng ko lag , pin sài đc 1,2 ngày, sài bền, máy có giá tầm này mà sài mượt vậy thì khỏi chê',
#  'Mặt sau nhám nhẹ bám tay chắc nhưng không để lại dấu vân, vỏ nhôm lạnh cho cảm giác mát rượi nên đừng ốp lưng khỏi mất cảm giác thực',
#  'Laucher máy nặng...',
#  'Hãng samsung giờ kiểu dáng thiết kế, chức năng, phần mềm còn thua mấy con oppo, trung quốc cùng tầm giá',
#  'mình chỉ cài dc chạm 2 lần sáng màn hình thôi',
#  'Pin khoẻ lắm, nghe to rõ, sóng tốt',
#  'Mới mua về dùng',
#  'Chụp hình mờ đã vậy còn bể nét ai cũng nói oppo chụp hình đẹp mình thấy chụp rất xấu 16 chấm chụp thua 5 chấm nữa',
#  'Máy lướt mượt ok',
#  'Ổn sang đẹp lâu hao bin nhưng sài mới mấy ngày thấy dễ trầy nhưng được tư vấn nhiệt tình mất hơn vài triệu nhưng được bảo hành an toàn hơn',
#  'Lúc đầu vẫn còn e dè nhưng khi quyết định mua thật đúng đắn',
#  'Màn sắc nét, pin trâu, 2 sim, khe cắm thẻ nhớ',
#  'Máy mua được 3 tháng',
#  'Theo mình dòng sp này với giá tiền và chức năng như vậy là quá tuyệt.',
#  'Cá nhân mình thấy điện thoại mạnh trong chơi game, đang gom tiền mua thêm',
#  'loa nghe to rõ chuông lớn, thiết kế nhỏ gọn, sóng sim mạnh rất tiện dụng...',
#  'Máy rất đẹp và nhẹ, chụp ảnh đẹp, sạc nhanh, nhưng pin nhanh tụt',
#  'Sản phẩm có Thiết kế sang trọng, nhiều tính năng thông minh, độ bền cao, chất lượng tốt, sản phẩm gọn',
#  'Hàng chính hãng nên hoàn toàn yên tâm sử dụng, chính sách bảo hành và chăm sóc khách hàng tốt',
#  'Nhỏ gọn .chụp ảnh bắt nét chậm .pin tốt .vào mạng nhanh .nghe gọi rõ ..',
#  'Mới mua hồi trưa, màn hình to, màu đẹp, mức độ hoàn thiện tốt',
#  'Facebook trung bình 2:30p mỗi ngày',
#  'Sản phẩm này rất ngon pin trâu game chiến mượt Sạc pin nhanh .vân tay nhảy loa ngoài to',
#  'Mình xài được 2 tuần rồi,mấy xài rất mượt chơi game rất tốt ko bị làng ,pin xài cũng được 1 ngay ,camera sau rất ok còn camera trước mình chụp thấy hình nó bị hỏi vàng,vậy là ok rồi rất tốt trọng tâm già ,mình cho 5sao luôn',
#  'Có mấy em nhỏ và mấy em lớn gia đình giàu có mua điện thoại thương hiệu nổi tiếng để chảnh với đời mới chê những hãng khác thôi.',
#  'máy nghe gọi to rõ máy phổ thông chỉ cần thế là hài lòng.',
#  'pin dùng rất ổn cho công việc hay dùng điên thoại',
#  'máy quá nhiều lỗi, lỗi vặt quá nhiều trong khi quản trị hệ thống chưa cập nhật phần mềm mình rất thích hàng việt nam',
#  'Mới mua, Nói chung dùng tạm, màn hình ok, chơi game pin tuột nhanh, so với giá thì chưa hợp lý',
#  'Sản phẩm rất tốt trong tầm giá 4tr5.chơi game mượt,pin trâu, sạc nhanh hình ảnh đẹp',
#  'Có khi đang dùng máy bi đơ ',
#  'Sản phẩm rất tốt về nghe gọi,',
#  'Làm sao để cài chạm hai lần sáng màn hình vậy mọi người',
#  'sản phẩm tạm ổn.Cấu hình yếu quá.Nokia chạy hệ điều hành adroi chưa thực sự tốt.',
#  'cảm ơn samsung đã đưa đt a10s ',
#  'Sao nhiều người chê này chê nọ thế nhỉ.chứ mình xài thấy ok.máy đẹp.pin tốt.vân tay mới đầu mua thì chậm thật.nhưng samsung vừa cập nhật pm ngay 25/8 giờ thì cải thiện rất tốt rồi.nói chung với giá tiền đó thì mình rất hài lòng',
#  'Cam sau ko được chuẩn lắm và các chế độ còn hơi rườm rà, tuỳ vào kĩ năng chụp nữa',
#  'Camera trước selfie ko có j nổi trội cở f11, f11 pro thôi',
#  'Bảo mật mở khoá bằng khuôn mặt rất nhanh',
#  'Sản phẩm dùng ổn định, nâng cấp lên bộ nhớ 32g thì sẽ họp lý hơn',
#  'Mọi thứ rất ok, chỉ hơi nóng máy, chắc do thiết kế mặt kính nên sể tỏa nhiệt',
#  'Duy nhất là con pin',
#  'Mới sắm 1 em màu đen tại tgdđ P9, TP Vĩnh Long',
#  'khg có gì bàn thêm',
#  'Tầm giá này tạm ổn',
#  'pin sai lâu',
#  'Máy đẹp xem yutub mạng4g không rõ nét.pin ổn phục vụ OK,mua sản phẩm online kèm quà tặng loa giá đỡ',
#  'Nhưng đt tốt thật',
#  'Máy thiết kế đẹp pin trâu màn hình sáng nhỏ gọn phù hợp với túi tiền của mình mua ở đmx nv phục vụ nhiệt tình vui vẻ luôn ủng hộ đmx',
#  'Mình không chơi game nên máy đủ dùng',
#  'Khi mới dùng phần mở khoá bằng vân tay không được nhạy, nhưng sau xoá cài lại thì giờ đã ổn',
#  'Màn hình siêu đẹp',
#  'Sau 15 ngày sử dụng tổng kết như sau : 1 : nếu để chế độ chờ và chạy tác vụ giải trí đơn giản như đọc báo, facebook thì pin trụ tầm 2 ngày',
#  'Kiểu dáng đẹp, thao tác mượt',
#  'Trước là bên ngoài, quá đẹp quá sang chảnh, cảm ứng mượt, camera phải nói trên cả tuyệt vời, sắc nét tới rung tay khi ấn vẫn rõ',
#  'còn mượt hay không, pin gì để thời gian đánh giá,...',
#  'Xài ổn mỗi cái youtube dg xem hay bị thoát ngang',
#  'thêm khoảng trăm bài hát, vài ngàn cái ảnh, dung lượng vẫn thoải gà mái nhé',
#  'Chơi game nặng hẳng thỳ k rõ nhưng nặng vừa phải thỳ con chíp helio p25 hoạt động tốt không hề thấy giật trong game ',
#  'Cũ người mới ta..mới mua về, xài thấy mượt..',
#  'Rất hài lòng , cho 5 sao',
#  'Cho em hỏi là, lúc em chưa cập nhật android lên 9.0 phiên bản UI 1.0, em chơi game không giật lag gì hết, và lúc em cập nhật lên android 9.0 xong thì đt trở nên lag giật nóng máy hơn trước, admin biết đt bị gì không ạ, admin giúp em với ạ, xin cảm ơn!',
#  'Nhân viên DMX tư vấn rất chu đáo vui vẻ',
#  'Đã nhận máy hôm qua, máy hoàn thiện tốt, màu bạc theo mình cho cảm giác sang trọng, màn hình hiển thị đẹp, thao tác mượt mà, cầm khá đầm tay, pin vẫn thấy ổn...',
#  'Máy khoảng 6 triệu lúc mua, máy mượt, camera chụp đẹp, màn hình tràn viền, chỉ có nhược điểm là vân tay ở mặt sau.',
#  'Sau 1 tuần sử dụng thì thấy rất thất vọng về quả pin 5000 ,để ko cũng hao pin rất nhanh ,chơi game thì hơi giật ,nói chung là sai lầm khi lựa chọn A9, Huawei đùng còn thích hơn',
#  'Sau 4 tháng sử dụng ngày nào mình cũng chơi freefive ít nhất là 3 tiếng mà giờ vẫn mượt và pin vẫn như lúc mới và mk có thêm vài nx như sau , thiết kế đẹp, nhất là bản màu đen ,loa trong và loa ngoài rất to và không bị rè màn hình thì độ sáng cao, hiển thị tốt , pin chơi freefive liên tục bằng wifi được hơn 5 tiếng, YouTube 1 tiếng hết 12p trăm , sạc 2 tiếng đầy và khi sạc máy rất nóng ,cam trước chụp xấu nhưng cam sau quá đẹp đặc biệt là chế độ xóa phông và chụp gần bật dấu chìm máy ảnh kép thì quá nét , mình đăng một bức ảnh chụp xóa phông cho mọi người xem',
#  'Mới mua được mấy ngày thấy sài ok , pin khỏe , 3g lên youtube xem bình thường , cảm ứng tốt , màn hình đẹp, chụp ảnh ok, sai không nóng máy, có cái wifi tải game chậm hơn máy khác chút xíu ',
#  'Sáng qua, mình ghé TTDD ngã 4 Âu Cơ, chị Anh và bạn Khoa ở đây rất nhiệt tình, đáng yêu! Mình đã xài dt dc 1 ngày, pin khủng, màn hình đẹp tràn viên, bộ nhớ hơn 22 GB, mượt, vỏ dt cực đẹp dc tặng tai nghe bluetooth 450k, kèm ốp lưng! Nói chung mình ưng ý và sẽ ủng hộ TGDD thêm nhiều!',
#  'Mất uy tín quá.',
#  'Màn hình khóa và màn hình chờ bắt buộc phải cùng 1 ảnh ạ',
#  'Tuyệt vời,không lo hết pin chụp hình cũng nét lại không nóng máy nữa,,,,rất ok các bác ak',
#  'Mua dc 1 tuần mọi thứ đều OK',
#  'Tóm lại nếu thích thương hiệu Samsung cũng như thích thiết kế của S10+ thì cứ mua nhé..',
#  'Máy xài tốt,mượt,pin trâu, chụp hình đẹp, bảo mật vân tay và khuôn mặt nhạy, sạc nhanh,',
#  'Dù đã dc hỗ trợ đổi máy khác nhưng để vô danh bạ phai mất từ 3s đến 10s',
#  'Máy chuẩn chụp ảnh nét âm thanh tốt độ bền cao nói chung chất lượng chuẩn giá cả hợp với mình',
#  'Mình chưa xài iphone bao giờ nhưng giờ xài mình rất thích',
#  'Máy sài rất ok, pin trâu , nhưng lại có nhược điểm là chơi game rất lag, nhiều lúc không vào wifi được',
#  'Máy rất tốt lại hợp vs giá mk ms lấy máy xong camera nét máy nhẹ cầm rất thích nhân Viên tư vấn nhiệt tình',
#  'Chất liệu thì tầm giá này k đòi hỏi nhiều',
#  'Nếu nhìn qua các dòng android của các hãng khác thì nhiều con hiện nay nhìn na ná Iphone',
#  'K hiểu sao.',
#  'Dùng từ ngày mới ra sp 9y 2019 đến giờ máy vẫn mượt ',
#  'Giá 2',
#  'Chỉ có 1 điểm duy nhất về mặt hình thức đó là thiết kế quá xấu ',
#  'Chức năng mặc hai lần sáng màn hình sau có lúc không sử dụng được có lúc sử dụng được',
#  'vân tay, khuôn mặt mở khoá khá nhanh',
#  'Đang tính bán ......',
#  'Chưa từng nóng máy/ pin sạc gần 2 tiếng full, nếu lướt Web xem phim cũng được hơn 2 ngày',
#  'Mới mua hôm đc 2 ngày.pin tạm ổn, vân tay nhậy cực, cảm biến khuôn mặt thì đeo khẩu trang cũng nhận diện đc.khá mượt rất tốt trong tầm giá',
#  'mìh đã mua tại TGDD máy sài rất mượt giờ mình cũg muốn mua cai sam sung J7 để sài tiếp của hãng SamSung máy sài rất tốt',
#  'Dùng để lướt mạng xã hội xem phim khá là ngon ,pin cũng ok rồi con này ram thấp chip cũ nên mới có giá đấy còn các bác có nhu cầu cao hơn thì quất con giá cao hơn là ok.hihi',
#  'Máy xài mượt chụp ảnh đẹp nhưng chụp ban đêm thì không được rỏ lắm',
#  'Cám ơn TGDĐ .',
#  'Nói chung tạm chấp nhận được',
#  'Luôn ủng hộ tgdd về cách phục vụ khach hàng và chăm sóc sau bán hàng',
#  'Điện thoại j6 này sài ok đáng tiền mình sài hơn một năm rồi vẫn ok chụp hình hoặc chơi game đều tốt',
#  'Bạn nào hay livestream trong công việc thì nên cân nhắc.',
#  '- Mới mua lúc sáng',
#  'Chup hinh thì rất đep',
#  'Máy ngon dùng tốt pin hết hơi nhanh không có camera và không lướt được web ',
#  'Máy ngon chơi game mượt',
#  'Thứ ba đt sam sung có quá nhiều ứng dụng ngầm nên dùng một thời gian tốc độ sẽ chậm, vì người dùng sẽ cài thêm nhiều ứng dụng khác, nói chung sam sung quá tham về khoản này',
#  'Mới nhận máy trưa nay với giá dc giảm 300k với giảm thêm 4% nữa',
#  'Pin dùng rất lâu, nghe nhạc, lên mạng thoải mái',
#  'Mới mua sáng pin trâu vãi 9h30 60% làm 2 trân lq nghệ nhạc youtube đến giờ là 2h30 còn 29% nghe cố cho hết pin mà lâu bực cả mình 😁',
#  'Pin xài lâu nhất là 4 tiếng , mua cái máy này cần có thẻ nhớ 8 gb trỡ lên, k thì mau đầy lắm',
#  'Nói chung là lúc đầu mới mua còn vài lỗi cũng sợ nhưng nghịch linh tinh là giải quyết được',
#  'Máy dùng rất tốt, cầm chắc tay, pin ok, sạc khá nhanh, chụp ảnh đẹp',
#  'Loa tặng kèm rất hay,',
#  'Tóm lại là ổn',
#  'Dùng 2 tháng và bắt đầu có dấu hiệu đơ máy ',
#  'Cám ơn Samsung nhé',
#  'Do xài chip MT6535 chơi game cũng ổn đôi khi hay đơ máy nhưng ko đến nỗi',
#  'Máy thiết kế đẹp sài ổn định mình rất thích,cảm giác cầm vừa tay ko quá to với màn hình 5.6 giá ok.',
#  'Sản phẩm rất tốt Thiết kế đẹp sang trọng Cấu hình ngon có thể xài 2 3 năm nữa mà không lỗi thời',
#  'Sản phẩm tốt,có điều pin hơi kém.Mua tại TGDD thị trấn Hợp Hòa Tam Dương VP,nhân viên ở đây rất nhiệt tình,chu đáo vá rễ gần,đặc biệt người quản lý tên Hùng rất chu đáo.',
#  'Cấu hình rất tốt với tầm giá',
#  'Rẻ, đẹp',
#  'Mình mới mua hôm nay, và dưới đây là nhận xét của mình về dòng điện thoại này Giao diện dễ sử dụng, icon ứng dụng mặc định không đẹp, phải tải chủ đề khác, sẽ nặng máy Không có điều chỉnh thời gian chờ sáng màn hình Độ sáng màn hình thấp, ở mức trung bình rất tối bằng mức thấp nhất ở điện thoại cũ của mình, chỉnh lên 75%- 80% mới vừa mắt, sẽ hao pin Loa to, chuông to, rung nhẹ, chất lượng âm thanh trung bình khá Camera trước mờ, Camera sau tương đối, ảnh bị tối không sắc nét Không có nhiều ứng dụng mặc định, dung lượng 16gb, khả dụng còn lại tầm khoảng 10gb Bắt wifi tương đối tốt, sạc pin hơi lâu, sạc từ 10% đến 78% mất 2h30, nếu muốn sạc đầy có thể cần khoảng hơn 3h, pin dưới 30% có thể sử dụng liên tục được khoảng 2h với tầm giá 3 triệu thì cũng đáng để suy nghĩ',
#  'Pin tầm khá: dùng sạc kèm theo thì khoảng một phút lên hơn 1%, sạc không đến 1 tiếng thì được 70% pin , máy mới mua nên chắc nhanh',
#  'Máy rất tuyệt, mượt mà, ram khỏe, bộ nhớ trong khủng, chụp siêu nét, dùng cả ngày không lo hết pin, cam thường nét, siêu phẩm.',
#  'Máy có hiệu năng tốt dùng rất mượt mà , thiết kế bằng kính và viền kim loại khá đẹp mức giá thấp .',
#  'Sản phẩm tốt cho 5 sao vì chơi game ổn pin ổn cấu hình chụp ảnh tốt khá mượt và nhân viên phục vụ vui vẻ nhiết tình',
#  'Tôi mua máy đc 2 tuần',
#  'Rất thích sản phẩm này..........',
#  'Phát wifi máy nóng',
#  'Máy này sử dụng rất mượt',
#  'Tạm ổn,nhưng cái dở là không có nhớ ngoài camera đẹp,pin tương đối.',
#  'Sản phẩm dùng mượt mà, chụp ảnh tốt, xem phim chơi game cho trải nghiệm tốt',
#  'nếu ai muốn mua con Oppo a7 này thì cân nhắc lại còn nhân viên TGDD dmx thì nhiệt tình tư vấn nạn chuyện rất vui vẻ',
#  'Hình thức đẹp, sạc nhanh',
#  'Vào cài đặt>hệ thống>cử chỉ>vuốt lên trên nút màn hình chính>tắt nó đi là ok',
#  'Giao diện quá xấu, nhìn rất rối mắt',
#  'chỉ cho 1* thôi và kbh dùng oppo ',
#  'Quá tuyệt vời, lúc đầu định mua Nokia 8.1 plus nhưng nhân viên tư vấn nên chọn con này',
#  'Cho các cụ dùng rất ổn chỉ là các cụ kêu cầm hơi mỏi tay do máy to, nặng hơn con nokia cũ.',
#  'Hiệu năng mượt, camera đẹp.',
#  'Sụt nhanh hơn sơ với đánh giá 4000mAh',
#  'chế độ bao xài 30 ngày rất yên tâm khi sử dụng',
#  'giá tầm trung nhưng chất lượng',
#  'Đô mượt mà.gems va mọi thứ..nhưng mình tiếc va cảm thông cho những bạn đã mua phải những May bị lỗi.nếu thật sự nhà sx va người dung đúng chất.đúng Đồng tiền thì mình tinh các bạn khỏi so sanh va phân vân khi xài oppo A83 an đứt mọi hãng khác',
#  'Tuy nhiên camera trước 5mp lại thua camera 2mp của samsung core prime 4 năm trước, zoom hình ra hạt sạn đen nhiều là do lỗi máy hay sản phẩm vậy',
#  'Tuy nhiên pin nhanh xuống',
#  'Máy bắt 4g và wifi mạnh',
#  'Dùng máy được 5 tháng ',
#  'Mình vừa mua hôm qua máy này sạc pin vào chậm sạc hơn ba tiếng được 60 phần trăm còn lại thì ok',
#  'Nhân viên tư vấn rất nhiệt tình và vui vẻ.',
#  'Mới mua sản phẩm hôm qua, về lướt kiểm tra máy ok.',
#  'Dung lượng nhiều nữa tha hồ quay video, tải ứng dụng đã luôn 😘',
#  'Mua',
#  'Mọi thứ tuyệt vời có mỗi camera chưa được đẹp lắm',
#  'Nói chung là rất tốt.',
#  'Mọi thứ đều tốt so với tầm giá, kết nhất là khoản pin',
#  'Nhược điểm: pin hơi yếu nhưng chỉ lướt web nghe nhạc thì có thể dc gần dc 1 ngày',
#  'Rất hài lòng ',
#  'mượt từ máy đến pin trong tầm giá này còn mong muốn gì hơn nữa phải ko?! Cảm ơn Mobiistar nhé!! Ai còn lăn tăn thì đừng ngại!! Feedback của mình có ảnh minh hoạ nữa để các bạn yên tâm mua dùng!! Ủng hộ Mobiistar nhé!! 💜💜💜💜💜💜',
#  'Camera kém',
#  'pin tụt quá nhanh 3g thì lâu lâu cứ tưng tưng còn tất cả còn lại thì ổn chơi game bậc max đồ họa vẩn không giật lag mình đang sài xiaomi note ram 4G bộ nhớ trong 64 nhưng bộ nhớ máy chiếm hết 1 mớ nên bộ nhớ còn lại là 51G ĐT này sạc cực nhanh khoản 2 tiếng là đầy pin',
#  'Mua đã 2 năm rồi rất tốt thích nhất PIN sài rất trâu mua cho con coi yotupe thiếu nhi cả ngày rất oke',
#  'mấy dùng dk nửa năm thì khe thẻ nhớ hỏng Z',
#  'tinh tế',
#  'Mình mới mua ip6 ngày 20/10/18 có nx là dùng máy ổn định, mượt, giao diện đẹp, nghe gọi loa ấm, rõ ràng, lọc âm tốt, pin dùng thoải mái đọc báo, xem phim được hơn 1 ngày, sẽ luôn ủng hộ apple',
#  'Sp khá ổn, pin tạm, thương hiệu dâu đen với cơ chế bảo mật trứ danh nhưng mà snap450 với tầm giá đó thì next',
#  'Máy thiết kế phải nói là đẹp, nhìn thích hết cả mắt, pin trâu khỏi bàn',
#  'Cấu hình ổn.camera hơi xấu.thiết kế rất đẹp.pin trâu.lướt wes mượt.mình ko hay game nên với mình như vậy là tạm ổn',
#  'Phía trước không được đẹp cho lắm',
#  'So với iphone 7 plus thì khoảng gaming nó hơi thua nhưng hoàn toàn không có giật lag (mới đầu mua về thì lag, sau mày mò mở được game turbo thì hết lag rồi) bù lại noa hơn iphone là pin trâu hơn và đang chơi game mà có cuộc gọi thì mình bấm nghe nó tự mở loa',
#  'Chiến liên quan OK',
#  'Sản phẩm này có thiết kế cong rất đẹp, màn hình hiển thị rõ, camera chụp hình tốt, chơi game mượt, giá lại quá mềm',
#  'rất tốt, đáng tin cây',
#  'Có giật lag nhẹ.pin ổn .nhân viên tư vấn nhiệt tình',
#  'Vừa nhận dc SP ở Daklak SP quá Tuyệt vời cảm ứng vân tay khuôn mặt cực nhạy ',
#  'Mình cũng mới mua thấy rất thích có nhiều ứng dụng hay pin trâu.hơi tiết là sắp có cái mới về xanh phỉ Thúy nhìn hình thôi đã thích rồi bt vậy để dành mua cái kia',
#  'Pin trâu, game chạy mượt, camera ở mức vừa phải, cảm ứng Vân tay tốt,sản phẩm thiết kế vừa tay trong tầm giá này thì ok,nhân viên phục vụ tốt',
#  'Máy mới mua 2 ngày Nhân viên xác nhận lỗi máy tai sao phải để KH chờ đến 7 ngày? Chán, that vọng !',
#  'Nếu tìm dt bền đẹp, pin trâu nên chọn, camera thj k dc tot cho lem, k phu hop dê choi game,phu hop vs ngui trung niên, làm quà tặng cho bố mẹ thì ok',
#  'Các tính năng phần mềm , hiệu năng',
#  'Máy huawei không thương hiệu như các hãng khác nhưng trong khoảng mức giá dưới 3 triệu thì cấu hình máy rất ok dùng rất ổn định, pin xài cũng đc lâu.',
#  'Cơ mà kình thích Oppo thì mình mua thôi',
#  'Nói chung là máy này chỉ xài chửa cháy thôi .mọi thao tác điều quá chậm .chắc có lẽ còn chíp mediatex này quá tệ',
#  'Mình rất hài lòng về chất lượng sản phẩm này',
#  'Nhu cầu pin trâu, chụp ảnh ổn, màn hình lớn thì dòng A series và J series của Sam làm tốt',
#  'chạy mượt lắm ',
#  'Về sPen thì cây bút cầm có cảm giác trơn trượt hơn so với các dòng note trước và phần đầu bút có cảm giác hơi rít nhưng cơ bản vẫn trong khoảng chấp nhận được ',
#  'pin 4000 mà rất mau hết',
#  'Qua tuyệt vời số với tầm giá',
#  'Sau gần 2 tuần sử dụng máy.',
#  'Tiếc là mình mua sớm quá.',
#  'NHÌN CHUNG XÀI TỐT',
#  'Nói chung sản phẩm rất tuyệt',
#  'Khôg có internet',
#  'Cam sau có chống rung OIS bản 217 thì không có, có ít cho việc quay video và chụp đêm',
#  'Thiết kế nam tính không uổng công chờ đợi ship hang từ Thái Nguyên về Bình Dương hết 7 ngày',
#  'So với máy của mấy thằng lol samsung thì giá của nó cao hơn nhưng chip yếu hơn dùng vài tháng có dấu hiệu lag nhìn thấy người quen dùng samsung mà thấy tức dùm luôn á',
#  'Mày Sài siêu tốt cảm biến vân tay nhạy chơi game không thấy hiện tượng lag nói chung giảm giá đến thế này là ngon rồi 👍👍👍👍👍',
#  'Lên mạng khá nhanh ',
#  'sạc bin rất nhanh,.',
#  'Mới mua hôm qua Máy to ngon phết nhưng load rất chậm, mình tải file về mà vào file của bạn k thấy, nó trôi đi đâu r k biết',
#  'chế độ chụp toàn cảnh cực chất lượng ,một ảnh toàn cảnh có thể được ghi đến 32 mb nên khi zoom về lên rất rõ ràng chi tiết',
#  'Sản phẩm có thiết kế đẹp, chụp hình cam sau đẹp, màn hình rộng, pin khá ổn, nhiều tính năng hữu ích, cấu hình ổn, hoạt động tốt',
#  'Mua hôm 13-5 ..dùng máy nóng ,nhanh hết pin giờ muốn đổi máy đc ko ad...........',
#  'một chiếc dien thoai nhu vay thi con gi bang...',
#  'H s9plus chỉ để nghe gọi, chụp hình',
#  'Thiết kế đẹp, màn hình hiển thị rõ, màu sắc đẹp, xem phim rất đã',
#  'Dùng ko khác Xiaomi note 4 là mấy, màn hình lớn hơn, pin trâu bò cũng như nhau, nv nhiệt tình, tạm thời ko có gì để chê cả',
#  'Có ai cập nhật android 7.0 cho A3 2017 chưa? Máy mượt hẳn ra đặc biệt sửa lổi vân tay nên rất nhạy luôn',
#  'Máy tệ nhất của Xiaomi, cực kỳ lag, cam xấu, chụp lấy nét rất chậm mà cũng ghi là cam AI',
#  'MÀN HÌNH: Nét, đẹp, có chế độ always ol display khá tốt giúp ko cần bật máy lên vẫn nhìn đc giờ',
#  'Máy sử dụng quá tuyệt vời , dơi rớt nhiều lần mà không sao nồi đồng cối đá đâm chất nokia dùng ngon bin hơn 2 ngày tuy mua máy cũ mà dũng vẫn cớ tốt , nói chung sp dùng ngon hơn 400k nhưng tiền nào của đó thôi',
#  'Máy đẹp , cam rõ nét , bảo mật khuôn mặt nhạy , pin trâu , màn hình sắt nét , cảm ứng mượt',
#  'Sản phẩm hay bị loạn cảm ứng sau khi sử dụng gần 1 tháng, máy dùng ổn, camera hơi bị quá màu gây rực rỡ cho ảnh',
#  'Lướt web và chơi game mạnh',
#  'Qua gần một năm sử dụng thì tôi có đánh giá như sau; -Cam trước gọi video mờ.',
#  'Thiết kế đẹp, dung lượng pin và cấu hình khá tốt so với các dòng cùng giá tiền',
#  'KaiOs như 8110 4g ram 512 sử dụng vài ngày đơ như cây cơ...chậm hơn rùa...thà thiết kế không hệ điều hành',
#  'Chơi game full cấu hình mượt',
#  'giờ em đang đau đầu ko biết có lên mang ra bảo hành hay là tự sửa luôn đây ',
#  'Máy s9 của em mới mua được 3 tháng, mà bây giờ dùng có tình trạng nhanh bị nóng, lướt facebook thôi mà cũng nóng.',
#  'Nhân viên TGDĐ rất nhiều tình, vì thế tôi rất tin tưởng và hay mua ở đây',
#  'Đặc biệt là tính năng quay chậm',
#  'Mua hồi tháng 12 năm ngoái',
#  'A7 128 gb..',
#  'Kích thước tương đối chỉ bằng S9 plus nên nói chung bỏ túi cũng ổn chứ không quá khó chịu',
#  'Cám ơn quản lý Thiểu tại tgdd 443_ Bạc Liêu đã nhiệt tình và tư vấn cho mình sản phẩm good như vậy.',
#  'J2 hay bị lỗi đứng máy và không tải nhạc về máy được wifi của máy thu sóng yếu.',
#  'Không có vấn đề gì, máy chạy rất tốt camera nét ok ,mạng chạy rất tốt.',
#  'Camera sau hơi tệ, cũng một phần vào màn hình HD nên xem cũng không đẹp mấy',
#  'máy mượt.',
#  'với tầm giá này thì ăn dứt máy androi dưới 3tr về hiệu năng...',
#  'Mới mua về sài thấy rất hài lòng .có tự động ghi âm cuộc gọi.đó rung rất mạnh.loa to rõ.loa nghe nhạc rất lớn.nói chung máy rẻ nhưng rất đáng đồng tiền bát gạo',
#  'Không hỗ trợ video call nên hơi tiếc.',
#  'Điểm trừ duy nhất là không lắp đc thẻ nhớ cùng lúc sim 2',
#  'Ko thích khả năng bắt sóng kém',
#  'Còn lại oke',
#  'Còn lại tất cả đều tốt',
#  'T khuyên thật lòng',
#  'Sản phẩm nova p3 này tạm ổn trong tầm giá nhưng có 1 số khuyết điểm như sau: -Bắt wifi hơi chậm -Pin tụt nhanh',
#  'máy xài tương đối tốt, nhưng sau 3 tháng không quay video, xem video thì giật liên tục..',
#  'cảm ơn anh chị TDDĐ và bác bảo vệ cute ở số 64-66-68 cao lỗ,đông anh đã giúp mình',
#  'Mới mua máy được hai ngày vào xem phim là báo lỗi sau đó màn hình chớp tắt liên tục',
#  'Mình chuyển qua chế độ 3G 4G mà vẫn vậy',
#  'Máy nhỏ gọn chắc chắn.',
#  'Chắc chịu mất 20% để đổi máy khác quá',
#  "Cập nhật 8.1 thì ổn hơn 30' mất 7%",
#  'Nếu ae nào mua dung để dùng vào công việc phải sử dụng đến 4G thì nên cân nhắc em A50 này',
#  'Tuy nhiên, camera trước không sắc lém, wifi bắt khá ổn, nhưng lướt web hơi chậm ko nhanh như htc',
#  'Pin tầm đó ổn cho ngày làm việc, có sạc nhanh nên cũng ổn hơn',
#  'Dễ thưong cực ',
#  'Chơi PUBG khá mượt',
#  'Mình nghĩ trong tầm giá này thì con này là ngon k chê được rồi',
#  'Máy Sài đơ thường xuyên muốn đập bỏ oy.cammara ổn ',
#  'Qua 1 tuần sử dụng thấy pin tốt, giao diện đẹp, có chế độ siêu tiết kiệm pin',
#  'Sản phẩm rất tốt ạ ĐT chơi rất mượt mà Chơi game free fiee em sẽ luôn ủng hộ TGDĐ',
#  'Pin rất ổn nếu ko xem phim nhiều thì đc 2 ngày',
#  'Ngon lành cành đào , thật sự quá chất lượng , mượt mà tốc độ xuất sắc ok yeah , nút home tuyệt vời quá đã tê tái haha',
#  'pin trâu...tóm lại rất tốt.',
#  'Vừa mua về màn hình tối quá so với j4 10 thì cái này dc 5,ko hiểu do lỗi máy hay dòng này nó thế',
#  'dt nay rat tot...choi game k bic lag la gi...chi giat chut it dv game nang thou...phu kien cua may cung de mua...len win 10 xai wa ok...app tren win10 nhiu hon cung du de xai nhu android ui',
#  'Có ai bị như vầy không, máy mới đổi được 2 ngày máy này có một vài lỗi như, loạn cảm ứng, bắt wifi kém, còn lại thì OK',
#  'Máy ổn định, pin ổn, dùng bình thường thì tận 2 ngày mới hết, có nhiều tính năng hay',
#  'Sao 1 tháng cảm nhận thì máy Sài ôn tốt ',
#  'Phải chi được 2 sim',
#  'Chất lượng hình ảnh và máy khá OK',
#  'Mọi thứ ok nhak',
#  'Máy dùng mượt, màn hình kích cỡ vừa dùng không quá lớn, chơi game cực đỉnh',
#  'Sau 2 tuần sd mình thấy sản phẩm tốt trong tầm giá,luc đầu sd pin còn 30%tắt nguồn nhưng sạc rui sd k bi nữa cấu hình,camera,loa,thì tạm k đòi hỏi nhiều,phục vụ nhu cầu online wifi suốt ngày,oncreen dc 6h30p còn 15%,mức sáng 100% và mình k gắn sim nha.',
#  'Loa khá chứ chưa ấn tượng lắm',
#  'Dưới 70% thì pin ổn định lại',
#  'Chơi game,xem phim ...',
#  'Đây là dòng smartphone giá cực rẻ của Nokia 2 nổi bật với dung lượng pin lớn và thiết kế chắc chắn nhờ bộ khung sườn nhôm cao cấp và mặt lưng nhựa nhám chống bám vân tay',
#  'Trừ lúc đầu vào video và nhạc phải mất thời gian cập nhận trong thẻ nhớ',
#  'Chấm điểm cho nà 1 Màn hình (HD) super amoled : 9.5 đ 2 Hiệu năng máy 4.4 triệu cho antutu 50.000 : 9.5 đ 3 Đa nhiệm khá tốt, máy chạy mát cả ngày : 9.0 đ 4 Pin 3300mah trâu bò : 10.0 đ 5 Camera sau tốt, trước khá : 7.5 đ 6 Thiết kế mỏng, đẹp, camera hơi lồi : 8.75 đ 7 Loa hơi nhỏ, thiết kế loa k ưng : 7.25 đ 8 Giá thành cần giảm nữa :) : 9.25 đ Mình thì mình thích những cái điểm cao nên mình chọn nó',
#  'camera sau 5',
#  'Mình sẽ tiếp tục ủng hộ sản phảm',
#  'Máy mượt, camera chụp rất đẹp, loa kép nghe to và rất hay, pin dùng tốt chứ không quá yếu như lời đồn',
#  'Còn Vân tay phải ấn mạnh dạn chút',
#  'Tôi đả sài oppo nài từ khi máy mới ra oppo n1 và oppo R5 và oppo R7 và hôm nai Tôi mới mua them cái oppo F3 plus nửa gì Tôi sài thấy tốt và ưng ý và độ nét thậy rỏ',
#  'Cam đẹp trong ban ngày tối thì tạm máy chạy ok trong mức giá',
#  'mua cho vk được hơn tháng, ko trực tiếp xài nhưng sơ qua thấy điểm yếu là màn hình hơi tối, camera trước quay chụp đều tối thui, đc cái selfi đẹp',
#  'Xử lý game nhanh',
#  'Hy vọng độ bền cao bù đắp.',
#  'Sp rất đáng để lựa chọn trong tầm giá',
#  '😆',
#  'Dùng được gần 1 tuần, pin nhanh xuống, máy hơi chậm khi, loa nghe không được hay lắm.',
#  'Còn pubg là tôi rất hài lòng.',
#  'Mình có lời khuyên cho những bạn nào có ý định mua máy này',
#  'Mặt sau bám dấu tay, cảm biến vântay thi thoảng không nhạy',
#  'nếu có thiết kế thêm két nước tản nhiệt xe tải thì quá ổn.',
#  'Camera chụp quá đẹp, pin không còn nhanh hết như ngày xưa nữa.',
#  'máy xài rất tốt,pin lâu trâu bò,máy mượt mà ít giật lag nha,nếu ai mua về xem phim,nghe nhạc,lướt web v.v.v là ngon,ai mua về chơi game và cài nhiều ứng dụng thì đừng mua,máy chụp ảnh đẹp,màn hình sắc nét coi phim rất hay,à ai mua về nhớ tùy chỉnh máy lại nha còn ai mua về mà ko biết tùy chỉnh máy thì mua điện thoại 5 triệu mà xài để khỏi nói máy lag nha,tiền ít đòi máy ngon',
#  'nhân viên phục vụ nhiệt tình chu đáo..',
#  'Mới mua hôm nay.giá quá mềm.haha.máy ngon mượt,cầm đã thích.định mua xs max.nhưng do to quá và k đủ tiền nên e lấy e này luôn',
#  'vừa mua về chiều nay...xài chưa qen lắm do quen với dòng ip rồi..nhưng phải công nhận xài sướng hơn ip nhiều',
#  'Chơi liên quân , free fire rất mượt, pin trâu, đt đẹp',
#  'Minh mới mua con a70 này dc 3ngay cảm nhận pin khá ổn , cảm ứng ko loạn như mấy bạn mua trước đánh giá , chơi game cũng mượt mà lqmb vào hơi khó khăn ko biết do lỗi máy hay do nph game .',
#  'Thiết kế nắp bật sang trọng',
#  'Để qua đêm với việc tắt hết các tính năng ứng dụng có thể gây hao pin nhưng qua đêm (khoảng 5 tiếng không sử dụng hao đến 15-18% pin).',
#  'Mình đang sử dụng máy, cũng được 2 năm rồi , máy xài tốt , ổn định, cầm chắc tay.',
#  'Nói chung mình hài lòng về sản phẩm này.',
#  '🐃🐂 gánh thêm màn hình 5.5 inch nữa quá tuyệt',
#  'Máy tốt đẹp có java chứ với có Facebook Google máy nghe nhạc tốt và nhiều chức năng',
#  'Chụp ảnh tuyệt vời',
#  'Ngoài ra rất ok...',
#  'Âm thanh cũng to',
#  'Chắc tẩy chay luôn',
#  'Sản phẩm tốt trong tầm giá mình dùng được hơn 1 năm rồi mà vẫn mượt.',
#  'Lỗi nhiều',
#  'Nhanh hết bin hay bị sập nguồn xong tự lại nên màn hình của máy điện thoại',
#  'Nói chung là sản phẩm đáng đồng tiền bát gạo ',
#  'rất ok, mong moi người mua nhiu nha hihihi!',
#  'Một từ thôi "ngon".Thiết kế bóng bẩy (của mình màu đen),chơi được liên quân,lắp thêm cái thẻ 16gb là đủ dùng.2tr vậy quá ngon,riêng cảm biến khuôn mặt chậm quá không nên dùng.',
#  'Sản phẩm mua được 1 tháng, đã cập nhật hết phần mềm, dùng ổn định, chưa thấy hiện tượng gì',
#  'Sử dụng dễ dàng',
#  'Mua được gần 1 tháng cảm thấy rất OK bin trâu chơi lq báo mượt xạc nhanh NV phục vụ nhiệt tình',
#  'mới mua được 1 tuần, kiểu dáng đẹp, bắt 3g mạnh wifi hơi yếu, chụp hình nét, pin hơi hụt nhanh',
#  'Sản phẩm ngon trong tầm giá',
#  'Máy đẹp cấu hình ổn mượt mà nhưng pin tụt hơi nhanh còn mọi thứ đều ok.............',
#  'nhưng vì sợ trầy nên mình phải xài ốp lưng chứ thực sự máy này ko sài ốp lưng mới thích , show ra hết dc vẻ đẹp của máy củng như nó cho mình có cảm giác cầm nắm sướng hơn ',
#  'chỉ cài được 1 vài cái cần thiết.',
#  'Mạng 4G ok.kết nối bắt sóng wifi cực mạnh, màn hình nhạy .k có hiện tương lag giật',
#  'Nhân viên phục vụ dể thương',
#  'Mọi thứ mượt mà',
#  'Cầu hình tốt ',
#  'Mình mới mua con này khoảng 1 tháng.Với giá này thì ok rồi máy có màn hình đẹp và sáng chơi game mượt.camera khá nét',
#  'Trong tầm giá này sam sung làm chưa tốt nếu mua sam mih nghĩ nên >5tr Hối hận',
#  'Chống nước chống bụi khá tốt',
#  'Bấm mở khóa nó kêu tiếng píp *Ưu điểm: Các chức năng cấu hình máy nhiều hơn điện thoại phổ thông khác 1',
#  'sp này loa to rõ k rè, nút bấm sướng giá rẻ k thể đòi hỏi hơn đc, nhiều tính năng hay',
#  'Mua được một tuần thì hư cục sạc, đem bảo hành thì TGDD thu lại máy và hoàn tiền',
#  'Có bị nào bị giống mình ko? Điện thoại lên mạng gọi video có10 phút mà máy nóng rát tay',
#  'Sản phẩm của Apple lúc nào mẫu mã đẹp Chất lương tốt',
#  'Sản phẩm tốt, giá vừa tầm',
#  'Pin tuột nhanh mac du dùng it.',
#  'Điện thoại tốt giá rẻ nhân viên nhiệt tình,vui vẻ,hoà đồng,nhiệt quyết,tư vấn quá trời luôn',
#  'Máy rất ok, lướt zalo fb messenger sài rất rất rất mượt Wifi mạnh ',
#  'Máy chạy 4g khá nóng, bắt sóng di động cũng bt, bắt wifi khá tốt; RAM 6G nhưng chạy đa nhiệm không tốt lắm khoảng 4-5 ứng dụng nhẹ cùng chạy là có cái phải load lại, con chip cũng ở mức tạm ổn; 3',
#  'Nói chung không có gì phải phàn nàn, ăn đứt các con của các hãng tên tuổi khác cùng phân khúc, mỗi cái là máy đẹp không thích dùng ốp nhưng lại dễ bị xước.',
#  'Đã mua được Đang sử dụng được hơn 1 năm sản phẩm vẫn rất tốt, chạy mượt không giống những dòng của Android',
#  'Hàng chất lượng cao ',
#  'Dùng đc 3 tháng.nc là rất ok trên mức mong đợi Còn mik cũng thấy lắm bạn chê này nọ.đem ra ss với hãng khác.nếu các bạn muốn máy tốt thì mua loại 20tr trở lên nhé.chắc chắn sẽ tốt',
#  'Nhưng được tặng đồng hồ đến 800k lận nên giá máy vậy rất hợp lí.',
#  'Có cái đầu không biết suy nghĩ àh.',
#  'Giá tầm chung! Thao tác ứng dụng cực kỳ mượt, pin trâu, bộ nhớ lưu trử thoải mái, giao diện hiện đại, màn hình tràn viền, camera dọc thời thượng! Xuất sắc',
#  'Kiểu dáng đẹp, camera trước và sau đều nét, pin trâu, có nhiều chức năng tiết kiệm pin, nghe nhạc cũng được, màn hình hiển thị ok, đi mưa trượt máy khá phê',
#  'Fps của máy là 30',
#  'nhưng thiéu khe căm thẻ nhớ',
#  'Hiện giờ m Không có cảm hứng với các dòng điện thoại khác',
#  'Rất hài lòng khi sử dụng',
#  'Chup hinh ko dep , doc wifi thi qua cham khi wifi o xa dt , noi that la mih rat rat rat hoi han khi mua san pham nay , mau sut gia so voi may khac.',
#  'Máy ok, camera ok , pin dùng cực tốt, xem phim nghe nhạc lướt wed liên tục hơn 5 tiếng mới hết, máy này quá ok',
#  'Đặc biệt là phiên bản Hàn Quốc và Mỹ',
#  'Mua được 1 tuần tôi nhận xét thế này , ưu điểm: thiết kế cầm rất đã với kim loại nguyên khối dưới 4 triệu vậy là ổn , cảm biến vân tay cực nhạy chưa đến 1 giây là mở lên ngay,camera chụp ảo diệu xài videocall cũng ổn, máy mượt khi chạy zalo, facebook, instagram cùng lúc nhưng rất kém và giật lắc khi vừa chơi game vừa sử dụng mạng xã hội',
#  'Máy nhìn quá đẹp,cảm biến vân tay nhạy,lên mạng nhanh,xem video trong và rõ,chụp hình ok ban đêm chụp vẫn đẹp,cấu hình ổn và mạnh nói chung là ok.',
#  'Máy dùng tốt ,nhân viên TGDD nhiệt tình.tư vấn chi tiết.nói chúng tất cả đang hoàn hảo.',
#  'Đây là sản phẩm có viền là nhựa sơn giả kim loại mà tư vấn là kim loại 100%',
#  'Pin ok.cảm ứng ko được mượt.đi ra hỏi tgdd thì báo đó mấy như thế.có ai bị cấm ứng ko mượt',
#  'Tôi đang làm việc tại vũng tàu.nhưng tôi muốn mua dt iphone x max.mà gd tôi ở quê đứng ra góp cho tôi được ko',
#  'Sản phẩm xài tốt, rất thích chiếc điện thoại này, thiết kế màu xanh nhìn rất đẹp, giá thành rẻ, pin xài cũng ok, không uổng tiền khi chọn dòng sản phẩm này, tôi rất hài lòng !',
#  'Sử dụng được 10 tháng',
#  'máy dùng tốt, chơi game xem phim đều tuyệt nhưng không có chức năng xác định thẻ sd là bộ nhớ mặc định nên khi tải file về phải tự chuyển qua rất phí thời gian.',
#  'Cảm biến vân tay mình thấy không quen nên khỏi xài vậy',
#  'Pin dùng được 1 ngày',
#  'Vivo y53 xài tốt , loa nghe ok , pin 2500 hơi yếu khi chơi game , nghe gọi ok giá thì hơi đắt tý nhưng bù con chip ngon mà hơi chác',
#  'Noi voi ve A3.(6).thiet ke dep.ngoai hinh gon vua tay .de su dung..camera chup anh cung sat net minh da..noi chung la minh thich dong A3(6).',
#  'Mình cũng ko chơi game nên thấy ok',
#  'Sản phẩm này chỉ có cái pin là vấn đề 4000 mà nhanh hết quá , ko kết nối mạng , lướt máy quan sát mà mất mẹ 2% trong chua đầy 1 phút , như vậy là nhanh lắm , mấy e ở điện máy xanh , Tuấn và nhi cũng hỗ trợ nhiệt tình , nói chung máy tạm được',
#  'Wifi yếu sóng 3g,4g cũng yếu pin đủ dùng',
#  'iPhone XR quá tuyệt vời với chíp A12 mạnh pin khủng cầm nấm chắt tay ,tuy màn hình có độ pg HD+ nhưng chụp ảnh đẹp vì iPhone mà,vậy mà ai cũng chê theo mình thì quá tuyệt vời.......ko thua gì ip XS MAx đâu nha các bạn nên mua......',
#  'Máy còn tích hợp Mi communicate là 1 diễn đàn; rồi mục phản hồi về các lỗi của máy ...',
#  'Máy ngon lắm chơi game mượt mà, không gjaajt lag chụp ảnh cũng rất đẹp, selfie góc siêu rộng luôn.',
#  'Nhỏ gọn cầm chắt tay với tầm giá này vầy là OK rồi loa rõ ràng .pin chưa sạc lần nào nên chưa ổn định hay sao mà hơi màu tuột quá',
#  'Thiết kế đẹp, pin tốt nếu đọc báo, lướt wed thì cỡ 1 ngày mới hết',
#  'Trên cả sự mong đợi',
#  'Gía rẻ cấu hình ổn mà xài y như dòng điện thọai cận cao cấp',
#  '7h onscreen',
#  'Cầm trên tay chắc chắn',
#  'Camera sau lồi nhiều, dễ trầy xước',
#  'Mặc dù đã tắt nguồn khởi động lại + tháo sim lắp lại.',
#  'Sản phẩm xài rất ok, tôi rất thích, chụp ảnh củng rất đẹp dù là camera trước hay sau hình ảnh rất chuẩn.',
#  'Máy mới mua thì xài tốt nhưng khi cập nhật xong là đây bộ nhớ trong, máy chạy không nổi luôn',
#  'thiết kế nữ tính, đường cong mềm mại, cấu hình cao giá phù hợp, mới mua nên chưa biết có bền không.',
#  'Theo tui danh giá thi may nay rất tốt phu hợp voi tui tiền các ban camera thi khoi che vao day cau Hinh hon manh lượt nhanh sac 3 tiếng may la day pin song trên doi can trai nghiệm 1 lan cho biết thích cai nao là mua dung hon các ban minh không phải la fax của hãng nào cả vi minh tung trải va suy nghi nen quyết dinh mua xong ve trai nghiệm thi quá đã noi chung la OK dung nen xem nhung danh gia che nay che nọ ma lam Phan Vân Chúc các ban thanh cong',
#  'máy không hề chơi game chỉ có lướt web nghe và gọi.',
#  'thiết kế thanh mảnh nguyên khối, sang trọng,cấu hình tầm trung phù hợp với nhũng khách hàng tằm trung',
#  'Màn hình to chữ lớn, lo to rõ, phím to dể sử dụng, pin trâu rất tiện dùng cho người lớn tuổi',
#  'Pin ok, chơi liên quân liên tục 8h',
#  'Trước mua ở viễn thông a dù còn 1 tiếng người ta cũng đổi trả nếu lỗi nhà sản xuất',
#  'Mà thấy nó hay bị bong ở mép nên gỡ ra luôn',
#  'Xài rất mượt, nâng cấp Android 9 phải nói rất nhanh, thao tác trên Android 9 rất tiện',
#  'Tui cũng mua hồi mới ra',
#  'Còn cam trước hơi mờ ',
#  'xài chán phèo, rẻ mà xài chẳng được gì cả ngoài cái mác smartphone dùng tính năng gì cũng chả hoàn hảo rất bực.',
#  'Xài những app bình thường như mạng xã hội, nhắn tin, đọc báo, xem youtube đều khá mượt',
#  'Xài gần 2 tháng, cảm thấy máy bị đơ, vân tay 1 chạm không còn nhạy nữa, pin tạm được.',
#  'Chỉ càng làm cho công nghệ nước họ phát triển chứ còn công nghệ trong nước ko có vốn để phát triển',
#  'Cục pdp cũng tuyệt vời sạc nhanh vãi, vừa chơi game vừa sạc vẫn vào ào ào.',
#  'Phải có bản vá tối ưu pin nữa thì tuyệt..không biết có nâng cấp hay bỏ rơi người dừng như oppo ko nữa..còn lại ok mượt',
#  'Nhận diện móng mắt rất nhạy',
#  'Mọi thứ đều ổn chỉ có chơi game lâu lâu giật lag khó chịu quá, còn cục sạc nhanh 45w sạc chỉ nhanh hơn sạc 25w tầm 10p không chênh lệch bao nhiêu',
#  'Máy mượt, cấu hình máy ổn đinh ,màu máy đẹp tươi sáng ',
#  'Nói chung tốt trong tầm giá.',
#  'Kết nối mạng đôi khi chậm',
#  'Máy tốt cấu hình máy mạnh',
#  'Sản phẩm tương đối tốt trong tầm giá này',
#  'Khuyên ai chơi game đừng nên mua.',
#  'Sản phẩm tốt rất tin dùng thế giới di động đã mua hàng rất nhiều sẽ ủng hộ tgdd dài dài',
#  'Vì vậy nên sẽ ko đc lòng các bạn sống ảo :3)',
#  'Mình mua đc 1tháng thấy mọi thứ đều OK cấu hình tốt pin khoẻ có mỗi cái là máy bám bụi quá',
#  'Pin kém, sạc chậm, gửi bảo hành sửa pin xong, sau hư loa gọi không được, thất vọng vô cùng, Máy kém bảo hành kém, đã từng xài như sau này không bao giờ.',
#  'Nâng cấp hệ điều hành 7.0 cho note5 chạy rất mượt',
#  'máy rất tốt',
#  'ok..',
#  'Sạc nhanh ngày đầu hơn 4 giờ mới đầy',
#  'Với người lúc ở nhà thì wifi, người đường thì 4g xuyên suốt như mình mà pin vẫn trụ đc đến tối.',
#  'mình mới mua con j8 đk 1 ngày',
#  'Nhân viên tgdd thì lúc nào chả nhiệt tình',
#  'Xài thường xuyên online tầm 1 ngày',
#  'Nhằm khi lướt facebook là message nhắn tin bị dính đa xoa Message tai lại nhưng kh đc',
#  'Bá đạo trong phân khúc dưới 11 triệu.',
#  'Có vài nhận xét: pin ngon- mượt hơn a9pro(rất mượt trong tầm giá)- vân tay siêu nhạy- có nhiều thao tác cử chỉ tiện lợi- mở ứng dụng và mạng mẽo nhanh',
#  'Sản phẩm này rất tốt chơi game mượt, phù hợp giá tiền, rất đáng đồng tiền, chụp hình đẹp, chơi game không bị lag.',
#  'Sao 3 tuần sử dụng thì rất tệ, đang xem youtube Facebook Lazada..',
#  'Ngày đợt giảm giá còn 6tr140 , chơi liên quan ko bị lag, mình thử test mới quận café rồi bắt wifi rất tốt hơn mấy khác, fps khoảng 35',
#  'Cứ mỗi lần tải Ulike về chụp là máy cứ bị lỗi như này, khắc phục bằng nhiều cách cũng y như vầy, tổng quan thì ok, chỉ có bị lỗi camera trước',
#  'Thiết kế đẹp và sang trọng chụp hình đẹp bin tốt 👍máy chạy rất mượt',
#  'Loa to rõ Chỉ với 150k có ngay điện thoại sài ngon lành',
#  'Tôi xin chia sẻ đôi điều, xài J5Prime được hơn 2 năm, vừa chuyển qua A8Star ngày 4/9/2019, thứ nhất là màn hình siêu to, 1 tay ôm không hết đâu, nên cẩn thận cầm nắm, thứ hai là mua màu trắng, nhìn sang, màn hình to nữa chứ, mọi người cầm em nó trên máy mới cảm nhận được đáng tiền so với mức giá 5.450 (mua online đợt cuối tháng 8 giảm 2tr, kèm sinh nhật tháng 8 giảm 240k), thứ 3 là đo antutu đạt hơn 140k điểm xíu (đo ngay ngày mới mua, về sau thì chưa biết), chơi Liên Quân vẫn bao mượt nhưng chưa chỉnh được đồ họa HD, vào game nhanh chơi ổn, có giật lag nhưng đảm bảo là do mạng, đừng ai phán xét do máy, vẫn đang dùng bản Android8 do muốn so sánh thử Android8 trên J5Prime cũ, Bixby thì hơi khó gọi nó ra (do dùng Tiếng Anh, và phát âm phải thật chuẩn nó mới nhận), rất nhiều chế độ cài đặt hay (như lọc ánh sáng xanh, chụp màn hình kiểu cuộn, DolbyAtmos, blabla), đánh chữ nhận xét thấy nhanh hơn J5Prime, độ trễ thấp, màu sắc hiển thị sắc nét, về 4g thì là chuẩn CAT6 nên cũng tùy thuộc vào gói mạng đăng kí và nhà mạng, wifi có chuẩn ac mới nhất, cũng ổn không như nhiều người chê, đa nhiệm ok, xài facebook, đọc báo mượt lắm, màn hình to nữa, xem phim bao phê, đeo tai nghe bật âm thanh vòm DolbyAtmos bao sướng, thứ 4 là camera, có chụp thử 1 tấm, xóa phông còn lẹm vô phần tóc áo chút, nhìn mất tự nhiên nhưng có thể do nền rối, chip xử lí không nổi, selfie đẹp, camera sau cũng đẹp (nhưng để chụp đẹp nhất vẫn là nơi đủ ánh sáng như ngoài trời), pin xài đủ 1 ngày, có thể qua ngày 2 nếu giảm các cài đặt ngốn pin, có NFC (này là truyền dữ liệu ở khoảng cách gần không cần wifi 4g, có thể thanh toán qua ứng dụng, chạm nhẹ là thanh toán...)',
#  'Tuy nhiên với giá tầm hơn 7tr thì dòng này khá ổn',
#  'Cách đây 1 tháng mua 1 cái màu xanh đẹp tuyệt vời cho e trai , và cách đây mấy ngày tiếp tục mua thêm 1 em màu vàng cho chị gái, máy dùng tốt, sắc nét, kiểu dáng thời trang, pin sạc nhanh và dùng lâu, nhân viên tư vấn nhiệt tình.',
#  'Máy phù hợp hsinh máy đẹp tuy hơi chậm nhưng nhìn chung là ổn vì hàng việt nên chấp nhận cho 5 sao.',
#  'dùng không đuộc tốt như mình nghĩ',
#  'Điện thoại giá hợp lý, dùng tiện dụng, chụp hình đẹp, dễ sử dụng',
#  'pin thì khõi chê vì quá trâu, chơi LQ max seting 5 tiếng bật chế độ tiết kiệm pin mà mất có 60%, android one thì quá mượt mà không vấn đề gì',
#  'Hehe',
#  'F1S64G 2017 5 🌟 Nhá',
#  'mang4 g ở mình yêu chuyên 3g thây mươt hon',
#  'Thiết kế máy đẹp, màu đen rất đẹp, mình là nữ nhưng vẫn thích màu đen, chụp hình camera sắc nét, ram 6gb nên lên mạng chơi game rất mượt, rất hài lòng về sản phẩm, có kháng nước kháng bụi lun.',
#  'chụp xóa phông tốt..sản phẩm rất tốt cứ mua đi ko thoi kẻo hết đó..',
#  'Sẽ nâng cấp lên, xài ức chế cực',
#  'máy này k có cảm biến tiệm cận à hay cài đặt như nào toàn phải kết thúc cuộc gọi bằng nút nguồn',
#  'Máy mượt với con chip A12, Pin ổn dùng cả ngày mới hết, màu vàng đẹp rất sang, nhân viên tư vấn nhiệt tình và vui vẻ.đúng là không chọn sai nơi để mua các thiết bị điện tử.',
#  'Sản phẩm dùng rất ok , pin cũng trâu đâu có nhanh hết như các bạn nói',
#  'Mới lấy 7plus về 2 ngày đem ra đổi trả vì lỗi nhỏ phần cứng tí thôi, dùng thì vẫn ko ảnh hưởng gì vì để ý rất kỹ mới thấy',
#  'Camera chụp đẹp ',
#  'Máy tốt nhưng mà Zalo gọi điện không có hiển thị lên màn hình chờ ( màn hình khóa ) ..',
#  'chất lượng ko tốt , máy nghe gọi nhỏ , hãng nên cải thiện vấn đề này ',
#  'Máy có nhiều chức năng ngon',
#  'Sản phẩm quá tuyệt vời, đã dùng 4 máy của huawei, mới mua con nova3 với con nova 3e cả 2 con đều quá ngon trong tầm giá, cảm ơn tgdd huyện an minh tỉnh kiên giang, sẽ ủng hộ tgdd dài dài ạ',
#  'Mình vừa mua đt này xong mới dùng thấy ok còn sau này thì chưa biết',
#  'Quá thất vọng về dòng oppo này, mình mua gần 2 tháng, tháng đầu tiên xài bình thường, sang tháng thứ 2 máy gọi cho ngta toàn bi màn hình đen',
#  'Máy bắt sóng wifi rất kém, pin dùng nhanh hết chỉ đc cái sạc nhanh đầy',
#  'khuyên thật lòng đấy',
#  'Mình không phải fan của hãg nào hixxx cảm nhận của mình khi dùng s9plus và cũng test với mấy ae xài iphone 8plus hay X rùi',
#  'quá thất vọng - mình mua máy được 1 tháng 8 ngày -máy tự cong màn hình ( chắc do pin ) ( máy nguyên không rơi , ko cấn móp - từ chối bảo hành - sạc pin không vào - mất sạc nhanh - máy lag nhiều khi tự nhẩy cảm ứng- gbye samsung',
#  'Ai nói vân tay tệ',
# ...
#  'Pin tạm không đến nỗi hao ^^ máy cũng mượt ..',
#  'camera thì cũng tạm ổn thôi ☺☺ nhân viên tư vấn rất nhiệt tình ..cho 5 sao lun .',
#  'Sản phẩm có thiết kế thon gọn, đầy đủ chức năng như 2 sim, nghe nhạc, nghe đài FM, bàn phím nảy nhắn tin thoải mái, giá rất rẻ, tôi đã sử dụng và rất hài lòng',
#  'Tuy nhiên, các cài đặt thông thường như danh bạ hay âm thanh khá phiền hà, đôi khi phát bực, với mình đây là điểm trừ lớn',
#  'Sản phẩm redmi 7a rất tốt, mượt mà với những tác vụ cơ bản hàng ngày như Facebook, Zalo, Mess, YouTube..',
#  'Xài các ứng dụng chụp ảnh màu rất xấu',
#  'Còn 1 điều này..',
#  'Nói chung máy thế này cũng OK rồi',
#  'Giá thành thấp',
#  'Tắt cập nhật miui với app đi, máy giá rẻ nên đừng ham cập nhật',
#  'Camera trước chụp ảnh hay nói chuyện facetime thì mờ',
#  'Máy dùng rất tuyệt vời, đặc biệt là màu tím rất dễ thương và sang trọng',
#  'Sài hoài không thấy hư',
#  'Mới nhận máy hồi sáng âm thanh tốt Chưa thấy lỗi gì chạy mượt , camera chuẩn nét, so với giá tầm trung vậy là quá ok',
#  'Pin trụ khá tốt, xài hết 100% thì được 1,5 ngày, chạy android 6 marshmallows mượt, chơi game thì pin tuột hơi khiếp .',
#  'Bỏ 7 triệu mua em này còn hơn cả Iphone',
#  'Máy đẹp ,sạc nhanh,pin trâu dùng dc lâu khi chơi game và quá mượt mà,không hối hận khi dùng máy oppo f9',
#  'Chân sạc bị lỏng',
#  'Mua thêm chiếc thứ hai , cảm nhận máy thiết kế đẹp , dùng tốt mượt mà với các tác vụ bình thường , pin 🐃 bò , âm thanh to rõ , nói chung chất lượng sản phẩm vô địch trong tầm giá không có đối thủ , nhân viên bán hàng và giao hàng tận tình chu đáo , rất tin tưởng khi mua hàng ở TGDĐ và ĐMX , very good',
#  'Sài tốt',
#  'Tóm lại là sản phẩm rất tốt',
#  'Tuy nhiên bạn nào tay bị ra mồ hôi cũng đừng quá lo vì tay mình cũng hay ra mồ hôi nhưng quét vẫn bình thường (hơi chậm)',
#  'Máy xài dc 4 tháng, mới cập nhật bản 133, mb..',
#  'Máy cấu hình ổn, không bị đứng, camera khá tốt, hợp giá tiền',
#  'Mình mua máy được một thời gian ,mic thu hơi kém ,loa trong nghe cũng bé.cái này cầm chọi chắc vui lắm :)), pin xài cả tuần chưa hết còn độ bền thì khỏi hỏi nhìn là biết nó cứng thế nào.',
#  'Tiền thay màn hình thà xài chán rùi mua máy khac vậy nản thật',
#  'Do không có nhu cầu chơi game nặng nên mình thấy máy phục vụ khá tốt cho nhu cầu cơ bản',
#  'Đã test pin rồi',
#  'Điểm trừ duy nhất loa lúc to , lúc nhỏ',
#  'Mới mua dc 2 hôm mh đánh giá như sau Ưu điểm: - Máy khá nhỏ gọn để vừa túi - Pin cũng ok xài nghe gọi lướt wed được 2 bửa',
#  'Mình chẳng phải fan của hãng nào cả nhưng trải nghiệm thế nào thì nói thế thôi',
#  'Ngày xưa không thích Oppo cho lắm nhưng từ ngày được mẹ tặng cho chiếc Oppo F5 này thì mình đã có suy nghĩ khác rồi',
#  'Máy hoạt động tốt k bị giật hay đơ ',
#  'Mong là sớm cạnh tranh toàn cầu giúp VN phát triển hơn nữa',
#  'sản phẩm chạy mượt màn hình đẹp và sắc nét, camera không đẹp lắm, nhưng xài hiệu năng cpu thì ổn định!',
#  'Nhân vion tgdd rất nhiệt tình,nói cười vui vẽ, rất hài lòng.',
#  '1 năm rồi vẫn ok',
#  'Máy GALAXY CORE 2 chạy chương trình tốt cảm ứng mượt, bộ đôi Camera trước và sau chụp hình nét, chơi game đồ họa mượt',
#  'Sản phẩm rất đẹp, chạy mượt mà, nhân viên phục vụ rất tốt, hòa đồng, vui vẻ.....',
#  'Pin tốt dùng cả ngày, sạc 5V-2A cũng nhanh',
#  'Samsung galaxy a7 xài tốt camera rất ok đẹp',
#  'Note 10+ là ngon nhất nhé! Không tận dụng hết tính năng của nó mà chê bai',
#  'Nghe các bạn đánh giá về 2 dãy loa ngoài thật sự đó chỉ là cái kiểu chứ nó là 1 bên loa và 1 bên micro máy sử dụng khá ổn wi-fi tốt camera không đc đẹp nói chung tiền nào của nấy',
#  'Tệ',
#  'Điện thoại sử dụng một thời gian xong chậm lắm, đặc biệt là lướt youtube như rùa',
#  'Game liên quân đồ hoạ đẹp',
#  'Từ trong ra ngoài',
#  'Xài một thời gian cỡ 2-3 ngày chỉ còn tải đc 4 ứng dụng NHẸ khá thất vọng nhưng nhìn chung khá đẹp',
#  'Điểm yếu của máy là pin nhanh hết quá.',
#  'Mua hôm 27/4 mấy ngày đầu dùng thấy OK lắm sáng 2/5 sạc đầy đi làm 7h đến 7h30 mới chơi 1 trận liên quân',
#  'Còn camera chỉ ở chế độ bình thường thôi',
#  'Nói về camera vì là dt không thể đáp ứng như máy ảnh chuyên nghiệp các bạn yêu cầu bởi dt nó có nhiều chức năng khác chứ ko chuyên đi xử lí hình ảnh như máy chụp ảnh dc',
#  'Thiết kế rất tinh xảo và đẹp',
#  '20tr như vậy là hư thận rồi ae',
#  'Pin chơi game liên tục trên dưới 4 tiếng',
#  'Máy thiết kế đẹp màn hình sáng nhỏ gọn hợp với túi tiền của mình nv tư vấn nhiệt tình vui ve luôn ủng hộ đmx',
#  'Hàng ngon',
#  'Thiết kế mang phong cách trẻ trung hiện đại, màu sắc tươi sáng, nhiều tính năng mà các dòng khác chưa có, camera rất sáng, nhiều chế độ chụp , pin dữ dụng khá lâu, độ bền lâu, âm thanh phát ra lớn',
#  'Pin trâu kinh khủng ',
#  'Điện thoại chạy ổn định, tiện dùng',
#  'Nhưng máy khung viền nhôm dễ bị trầy xưoc thêm nữa là ko có nhiều tính năng như sam sung hệ diều hành hơi gò bó nhưng ổn định.',
#  'Cho 10 * lùn kkkkkk',
#  'Buồn 😞.',
#  'Đt tốt..loa lớn bề ngoài đẹp.',
#  'Mình đi Thailand lắp sim bên đó mà kg dùng được.',
#  'Ở mức giá tầm trung như này, thì chiếc dt này là một trong những sự lựa chọn tốt trong tầm giá.E đã mua tại cửa hàng tgdd ở Mỏ Cày Bắc, Bến Tre, trưa nay',
#  'Thiết kế của máy cũng tương đối đẹp',
#  'quan trọng là máy rát rạt ích nóng.',
#  'Hơn nueax giá cũng tạm được vừa túi tiền ',
#  '- Mình thấy máy xài cũng rất bình thường',
#  'Những phần khác thì tạm được',
#  'màn hình thì không sướng bằng tấm nền IPS nhưng vẫn khá tốt.(mình vẫn thích tấm nền IPS của sony hơn) .phím home cảm biến vân tay nhạy ,tốt',
#  'Mạng hỗ trợ qá ổn định 😊 mình vẫn muốn đổi con p30 hãng huawei',
#  'Dùng màn hình đẹp, pin hơi yếu so với dòng A, wifile bắt khoảng cách xa yếu hơn dòng lumia',
#  'Quản lí ram kém.',
#  'Dùng ol facebook liên tục dc 2h',
#  'Chi có cái tội chơi liên quân lâu lâu hay bị đơ khi kết thúc trận, ngắt kết nối wifi rồi kết nối lại mới được, không biết do mạng hay do máy nữa',
#  'Pin thua xa note 9, mình cũng dùng note 9 dùng cảm giác sướng hơn nhiều, khi nghe quảng bá của ss mình quyết định chuyển sang ss 10+ nhưng thật sự quá thất móng Kết luận: khi dùng ss 10+ này mà đòi so sánh với ip x max thì ss lên xem lại, máy quá kém, thật sự ng sử dụng quan trọng nhất sau này là sự ổn định, mượt mà, nhưng mình dùng s10+ quá thất vọng, sau gần 10 ngày mình lên thế giới di động đổ ngày ip xmax, lưu ý mình đang dùng ipx.',
#  'Tôi thường dùng em nó để kiểm tra hoạt động cua nhiều nhân viên với kết nối thông qua camera',
#  'tốt trong tầm giá, youtube, fb, zalo, game,....',
#  'Phải bấm nút home rồi mới tắt đc ứng dụng',
#  'Pin trâu dùng chiến game onl liên tục nuốt trọn 1 ngày máy mượt không có gì để chê , camera đẹp',
#  'Sử dụng 1 tháng rất hài lòng phin rất trâu xài lâu ko nóng máy ,âm thanh 2loa rất hay',
#  'Máy OK so với tầm giá',
#  'Mình đã mua 6 cái mobell m589 rồi ,dùng quá thích,pin trâu,loa to rõ.sản phẩm quá tốt.cho 5 sao',
#  'Sản phẩm này rất tốt chơi game rất mượt camera chưa hình như thất thiết kế liền thoái cầm rất vừa tay',
#  'Sài văn ok ',
#  'Tuy nhiên nói đi cũng phải nói lại là thiết kế S10+ rất đẹp, màn hình tràn viền cũng đẹp, nốt ruồi cũng đẹp tuốt',
#  'Sản phẩm đẹp màu xanh khá bắt mắt, tỉ lệ 18:9 cx ok, máy dùng tốt ',
#  'Màn hình rộng nhưng độ phân giải chưa cao',
#  'toa ro ',
#  'lướt web .',
#  'Đã mua sài 6 tháng nay',
#  'Lướt web tốt',
#  'dòng này thiết kế đẹp mỏng nhẹ thời trang,cấu hình tương đối ổn xài rất ok pin cũng khá tốt!',
#  'Máy hoạt động ổn định, camera đỉnh so với giá.',
#  'tôi có mua 1 máy màu đen đỏ',
#  'Dùng đượcc 1 năm, thấy máy chạy vẫn khá ổn có điều pin hơi yếu, bộ nhớ trong ít quá, máy nhanh nóng hơn bình thường, máy chủ yếu phục vụ chụp ảnh.',
#  'Mình dùng ít chức năng mà đã vậy rồi',
#  'Tôi mới mua được 1 ngày',
#  'Lumia 540',
#  'Dùng cơ chế 1 tay giống iPhone thì máy sẽ có hiện tượng lag nhẹ',
#  'Samsung là một tập đoàn lớn, điện thoại thiết kế đẹp bền bỉ cùng thương hiệu, giá tuy cao hơn những dòng smart phone android khác nhưng bù lại cấu hình tốt, chất lượng, camera đẹp, linh kiện nguồn gốc rõ ràng, tôi yêu samsung sau lúc giải quyết note 7, tuy s6 là một smartphone cao cấp của năm trước nhưng vẫn nhanh và ngon hơn nhiều smart phone cao cấp năm nay',
#  'Rất đáng để mua..',
#  'Vừa mua đc 3 ngày mà sài thì k vừa ý',
#  'Lướt web,fb,youtube thì chưa được 1 ngày',
#  'Mình mới mua hôm qua ',
#  'Nói chung hài lòng khi chuyển qua IP.',
#  'Thiết kế đẹp, máy chạy mượt, chỉ có quãng cáo hơi nhiều, tốn pin',
#  'Nói chung là mình thích dùng dòng huawei lắm',
#  'Mình là fan nokia nên trước giờ vẫn theo nokia, lần này sắm con nokia 7 plus này cũng không làm mình thất vọng',
#  'mới mua em này về cảm nhận chơi game không được mượt nhưng camera chụp rất tốt chỉ tiếc về phơi sáng thì điều chỉnh tay khó nên chụp hay bị cháy sáng nhiều.',
#  'Nhưng mình vẫn thích em này',
#  'máy tàu nó vấn thế tôi mong ..',
#  'Máy sử dụng cũng khá tốt mà tốc độ không bằng 5se xử lý nhanh hơn nhiều.',
#  'Camera chụp chữa cháy tạm được, Rom trống khoảng 2GB',
#  'Nhưng nhược điểm là máy xuống pin rất nhanh, dùng lâu thì tự động thông báo hết pin và tắt nguồn, bật máy lên thì vẫn còn pin',
#  'Cần cải thiện pin',
#  'Pin cũng khá lâu so với điện thoại khác',
#  'Máy chậm mà giá ở mức 4tr990 thì không OK lắm,dùng mới 2 ngày đã lag, không tải game mà còn vậy 👎👎',
#  'Máy dùng ổn định chụp hình đẹp, thiết kế vừa tay, màn hình tràn viên dù xem phim hay lướt web đều rất ok.',
#  'Màn hình hơi nhỏ, nhưng bù lại pin dùng được lâu, loa nghe to, rõ, giá thành không quá cao',
#  'Rất tốt.bin sài ngon.tôi mua liền 3 cái cho gia đình.mua nhiều còn được khuyến mãi nữa chứ.mỗi cái được khuyến mãi năm mươi ngàn .rất ôkê',
#  'Chơi pubg k giật lác tí nào',
#  'Mới mua được 2 ngày nhưng thấy máy ổn định pin khỏe chơi mượt phải nói là máy ngon trong tầm tiền',
#  'Nhân viên TGDD thì rất tuyệt vời.',
#  'Sản phẩm có mặt trên thế gian này là một tuyệt phẩm của Samsung',
#  'Tôi đã dùng tôi thấy quá hài lòng về chất lượng cao cấp của oppo A71 tôi rất thích',
#  '-Camera sau chụp lấy hình hơi chậm',
#  'Mình có hỏi bên tgdd thì nói ứng dụng chưa dc cập nhật',
#  'Mặc dù đã xài Wi-Fi với 4G, nói chung rất ức chế khi chơi liên quân.',
#  'Ngoài hơn con A20 về camera thì mọi thứ đều kém hơn rất nhiều từ công nghệ màn hình cho đến con chip',
#  'Sản phẩm tốt, cấu hình ổn định ko bị đứng, pin bền, xài đuợc lâu',
#  'Pin dùng rất bền',
#  'mua máy về dùng cũng vài tháng, xài thấy bền và tốt nhưng vỏ ngoài dễ bám bụi và trầy lắm',
#  'Cảm ứng k nhạy lắm,',
#  'Realme C1 là một lựa chọn tốt ở phân khúc giá rẻ:))',
#  'vào mạng 3g như hơi yếu..😑😑',
#  'Mua máy cũ tại Lê Đức Thọ, bh còn 10 tháng, máy vẫn mới tinh ko 1 vết trầy, pin trâu, màn trong, vuốt trơn rất sướng, cam chỉ tạm, máy mát, nv phục vụ chu đáo, tiễn ra tận ngoài đường',
#  'Chỉ có khi chơi game thì có người gọi đến điện thoại k reo chuông và k hiển thị cuộc gọi lên hết màn hình mà chỉ hiện ở trên chữ rất nhỏ lúc hiện lúc tắt, làm mình k biết có người gọi tới',
#  'Không hối tiếc với số tiền bỏ ra',
#  '.nói chung là tất cả đều vẫn ok.',
#  'Mới mua hôm nay, nhìn tổng thể sp tốt, nhân viên tư vấn hỗ trợ tốt, đánh giá 5 sao',
#  'Cầm nặng tay mỗi tội hơi dày vì viên pin lớn',
#  'Máy cái j cũng ngon chỉ có 4 phần k tốt lắm 1 bắt Wi-Fi hơi yếu 2 ghi màn hình bị dính 3 phím home 3 3 phím của mấy có nhiều ứng dụng k tắt 4 camera k đc như mong đợi Ngoài ra đều ok OK nhất là sạc 5p đc 20%',
#  'Mình thấy máy rất tốt',
#  'Máy này rất phù hợp để xài chung với con cảm ứng là cái sơ cua',
#  'Pin trâu,sạc pin nhanh,màn hình to,AI thì khỏi bàn,nói chung là OK rồi..........',
#  'Nhân viên chu đáo nhiệt tình vui vẻ ^°^ Máy xài tốt mượt wifi mạnh pin ổn camera chụp rất đẹp 5*',
#  'Camera sau 3 cái nhưng chỉ có cái giữa là thật còn 2 cái là giả.pin thì ok vì trâu bò.máy mượt.còn độbền thì thời gian mới biết',
#  'Nếu không có nhu cầu game hầm hố như các bạn nam, con này hoàn toàn ổn',
#  'Nghe gọi thì được cái là có thể vừa gọi điện , vừa làm việc riêng trên điện thoại , có thể ghép ảnh vào danh bạ (cái này khá là thú vị :) ) ',
#  'Cảm thấy thất vọng về samsung galaxy a7 2018 mới sài hơn 3 tháng mà đã tắt nguồn mở ko lên',
#  'Sản phẩm đẹp, mượt và rất ít hao pin, để từ tối tới sáng chỉ mất 4 phần trăm pin',
#  'Máy ổn so với giá 15tr',
#  'Lướt web nhanh, chơi game mượt',
#  'Cảm giác cầm nắm tốt, camera chụp thiếu sáng không tốt lắm còn về hiệu năng thì với giá đó không có gì phải bàn',
#  'Mình mua máy được một thời gian khá lâu r mình thấy máy đánh game cx đc',
#  '5 sao.',
#  'Cam khá ok ',
#  'thất vọng vì đã chọn nokia3 mua 3 hôm lỗi màn hình, mang đến tgdđ đổi lại phải chờ gửi hãng thẩm định 8 hôm vẫn chưa có kết quả',
#  'Mình có dán máy nhưng nhân viên sơ ý rạch hơi mạnh nên mặt lưng máy mình có 1 đường',
#  'Sản phẩm ok pin trâu máy xài liên tục mấy giờ mà ko nóng',
#  'TôI rất hàI lòng về chất lượng sản phẩm',
#  'Chơi game pin quá trâu 2 tiếng tuột 15% pin',
#  'Mình toàn lưu file lên OneDriver, mở bằng máy tính hay điện thoại đều được, rất tiện',
#  'Xài được 1 tháng',
#  'Sản phẩm tốt sau khi sử dụng 1 tháng chưa thấy 1 lổi nào hiệu năng thì khỏi phải bàn với chíp sdagaron 845 mượt và nhanh hơn galaxy s9 dùng chip Exynos',
#  'Chất lượng hoàn thiện khung vỏ chưa tốt, nhiều khe hở giữa phần khung kim loại ở giữa với 2 dải nhựa ở 2 đầu máy, khe hở phím âm lượng và phím nguồn lớn (dù đổi đi đổi lại các máy ở cửa hàng nhiều lần) cảm giác nhấn 2 phím này không tốt bằng nokia 3',
#  'Bản thân mình ms dùng chưa dk bao lâu đã trang bị đầy đủ từ ốp zin đến cường lực rùi ',
#  'Nói chug lèa cũg rấc ô kê, chơj game ZjngSpeed mobile rấc êm',
#  'Phím dễ bấm rớt mấy lần mà thấy bình thường',
#  'sản phẩm rất tốt nhưng không có tiền mua thấy mọi người ai cũng đánh giá tốt nên mình theo luôn',
#  'Chơi game thì tạm được',
#  'bật tiết kiệm pin giúp pin trâu hơn nhưng một điểm hay là dù bật tiết kiệm pin hiệu năng vẫn k giảm .',
#  'Cấu hình ngon, cầy pubg thì khỏi bàn',
#  'Người Việt Nam dùng hàng VN',
#  'Camera chup hình đẹp long lanh luôn',
#  'Đẹp mọi mặt , tốt mọi mặt nhưng pin hơi yếu thôi',
#  'Máy thiết kế đẹp pin dùng ok .nhân viên tư vấn nhiệt tình rất hài lòng về sản phẩm',
#  'Thứ ba sóng mạnh...cảm giác cầm nắm rất vừa tay....nhỏ gọn....lúc buồn có thể lên Facebook cùng dc...những giải trí chơi game thì phải nạp tiền .....tóm lại mình cảm thấy giá tiền như vậy quá tuyệt vời...',
#  'Nhớ cái lúc mới mua về để cày Au mobile ngày đêm',
#  'Mình thử gở greenify thì sạc đầy pin gần 2 tiếng mới đầy.android 7.0 trên dòng A 2016 cho phép tắt sạc nhanh nhá.',
#  'Chỉ có điều là bộ xử lý hơi chậm Nói chung tầm giá này là quá Ok',
#  'Định mua em này mà thấy mọi người chê nhiều quá',
#  'chơi game ko tốt lắm',
#  'Mình mua được 3 ngày,gpu rơi vào 22k điểm chơi liên quân hay pupg chấp nhận được.màn hình to đánh liên quân dễ thấy địch từ xa 🤣🤣 Con này mọi thứ bình bình...dành cho mấy con mọt phim hay youtoube ,mình chỉnh trong cài đặt mọi thứ tối thiểu nhất coi youtobe đc hơn 18 tiếng liên tục',
#  'Chờ oppo A7 cập nhật android 9 và coloros 6',
#  'Tiện lợi cho ai 2 tài khoản ko cần out ra log vào',
#  'sản phẩm thiết kế đẹp cầm vừa tay, cảm ứng mượt mà, chụp ảnh sắc nét và đẹp',
#  'Cam trước ok',
#  'Tổng thể chiếc đt rất đẹp',
#  'Nhưng khi dùng ap thì góc cam khá gần.',
#  'Chỉ có điều là máy khá là kén phone tai, còn lại mỏi thứ điều ổn',
#  'Thiết kế sang trọng, giá thành hợp lý, cấu hình ổn định, camera sắc nét, rất ok.',
#  '10* cho nhân viên tgdd huyện mường tè - lai châu.tư vấn nhiều tình☺☺',
#  'Pin 4000m mà thay thua pin của iPhone 6 plus nữa nhanh xuống pin ghê ko trâu tí nào',
#  'Lúc đầu dùng vài tuần pin tụt rất nhanh, nhưng sau gần 1 tháng pin thì tạm được giá 2990000d thì ok,có cái điều mình chưa hai lòng cắm sim phải tắt nguồn mở lại máy mới nhận được sim,như vậy mình không thích không hay chắc do chíp kirin của huawei.mong nhà sản xuất khắc phục lại điều này',
#  'Ae cân nhắc....chụp ảnh đêm rất kém',
#  'Dùng 2 sim thì bị mất sóng',
#  'Quá Tuyệt vời cho note 8.pin tạm được.nhưng may có sạc nhanh nên ko lo ngại về pin.vs mức giá 12tr.so vs note 9.19tr thi nên chọn note 8.',
#  'Iphone 6s 32g thiết kế máy đẹp sử dụng mượt mà camera chụp ảnh đẹp',
#  'Vừa mua máy 1 ngày',
#  'Điện thoại thiết kế đẹp Sang trọng nhưng ram hơi bị ít Em mua ở các cửa hàng nhỏ giá 3tr400 Về lên TGDĐ thì thấy mình bị lừa mấy trăm nghìn',
#  ...}

# %%
df_sentences = pd.list(contents)
